# %% [markdown]
# Cálculo da área

# %%
base = float(input("Digite a base:"))

altura = float(input("Digite a altura:"))

area = base * altura

print("A área do quadrilatero é:" , area)
# Out:
# Digite a base: 5
# Digite a altura: 5
# A área do quadrilatero é: 25.0
